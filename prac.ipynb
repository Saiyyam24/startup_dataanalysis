# %%
import pandas as pd

# %%
df = pd.read_csv("startup_funding.csv")

# %%
df
# Out:
#       Sr No Date dd/mm/yyyy                  Startup Name  \
# 0         1      09/01/2020                        BYJU’S
# 1         2      13/01/2020                        Shuttl
# 2         3      09/01/2020                     Mamaearth
# 3         4      02/01/2020  https://www.wealthbucket.in/
# 4         5      02/01/2020                        Fashor
# ...     ...             ...                           ...
# 3039   3040      29/01/2015                    Printvenue
# 3040   3041      29/01/2015                      Graphene
# 3041   3042      30/01/2015                Mad Street Den
# 3042   3043      30/01/2015                     Simplotel
# 3043   3044      31/01/2015              couponmachine.in
#
#         Industry Vertical                            SubVertical  \
# 0                  E-Tech                             E-learning
# 1          Transportation              App based shuttle service
# 2              E-commerce  Retailer of baby and toddler products
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3044 entries, 0 to 3043
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sr No              3044 non-null   int64
#  1   Date dd/mm/yyyy    3044 non-null   object
#  2   Startup Name       3044 non-null   object
#  3   Industry Vertical  2873 non-null   object
#  4   SubVertical        2108 non-null   object
#  5   City  Location     2864 non-null   object
#  6   Investors Name     3020 non-null   object
#  7   InvestmentnType    3040 non-null   object
#  8   Amount in USD      2084 non-null   object
#  9   Remarks            419 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 237.9+ KB

# %%
df.drop(columns={'Remarks'})
# Out:
#       Sr No Date dd/mm/yyyy                  Startup Name  \
# 0         1      09/01/2020                        BYJU’S
# 1         2      13/01/2020                        Shuttl
# 2         3      09/01/2020                     Mamaearth
# 3         4      02/01/2020  https://www.wealthbucket.in/
# 4         5      02/01/2020                        Fashor
# ...     ...             ...                           ...
# 3039   3040      29/01/2015                    Printvenue
# 3040   3041      29/01/2015                      Graphene
# 3041   3042      30/01/2015                Mad Street Den
# 3042   3043      30/01/2015                     Simplotel
# 3043   3044      31/01/2015              couponmachine.in
#
#         Industry Vertical                            SubVertical  \
# 0                  E-Tech                             E-learning
# 1          Transportation              App based shuttle service
# 2              E-commerce  Retailer of baby and toddler products
# ...

# %%
df.rename(columns={
    'Sr No': 'sno',
    'Date dd/mm/yyyy':'date',
    'startup Name':'startup',
    'Industry Vertical': 'vertical',
    'SubVertical':'subvertical',
    'City  Location':'city',
    'Investors Name':'investors',
    'InvestmentnType':'rounds',
    'Amount in USD':'amount'
},inplace=True)

# %%
df
# Out:
#        sno        date                  Startup Name             vertical  \
# 0        1  09/01/2020                        BYJU’S               E-Tech
# 1        2  13/01/2020                        Shuttl       Transportation
# 2        3  09/01/2020                     Mamaearth           E-commerce
# 3        4  02/01/2020  https://www.wealthbucket.in/              FinTech
# 4        5  02/01/2020                        Fashor  Fashion and Apparel
# ...    ...         ...                           ...                  ...
# 3039  3040  29/01/2015                    Printvenue                  NaN
# 3040  3041  29/01/2015                      Graphene                  NaN
# 3041  3042  30/01/2015                Mad Street Den                  NaN
# 3042  3043  30/01/2015                     Simplotel                  NaN
# 3043  3044  31/01/2015              couponmachine.in                  NaN
#
#                                 subvertical       city  \
# ...

# %%
df.set_index('sno')
# Out:
#             date                  Startup Name             vertical  \
# sno
# 1     09/01/2020                        BYJU’S               E-Tech
# 2     13/01/2020                        Shuttl       Transportation
# 3     09/01/2020                     Mamaearth           E-commerce
# 4     02/01/2020  https://www.wealthbucket.in/              FinTech
# 5     02/01/2020                        Fashor  Fashion and Apparel
# ...          ...                           ...                  ...
# 3040  29/01/2015                    Printvenue                  NaN
# 3041  29/01/2015                      Graphene                  NaN
# 3042  30/01/2015                Mad Street Den                  NaN
# 3043  30/01/2015                     Simplotel                  NaN
# 3044  31/01/2015              couponmachine.in                  NaN
#
#                                 subvertical       city  \
# sno
# 1                                E-learning  Bengaluru
# ...

# %%
df = df.drop(columns={'Remarks'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3044 entries, 0 to 3043
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sno           3044 non-null   int64
#  1   date          3044 non-null   object
#  2   Startup Name  3044 non-null   object
#  3   vertical      2873 non-null   object
#  4   subvertical   2108 non-null   object
#  5   city          2864 non-null   object
#  6   investors     3020 non-null   object
#  7   rounds        3040 non-null   object
#  8   amount        2084 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 214.2+ KB

# %%
df['amount'] = df['amount'].str.replace(',','')
df['amount']
# Out:
# 0       200000000
# 1         8048394
# 2        18358860
# 3         3000000
# 4         1800000
#           ...
# 3039      4500000
# 3040       825000
# 3041      1500000
# 3042          NaN
# 3043       140000
# Name: amount, Length: 3044, dtype: object

# %%
df['amount']=df['amount'].fillna('0')
df['amount']
# Out:
# 0       200000000
# 1         8048394
# 2        18358860
# 3         3000000
# 4         1800000
#           ...
# 3039      4500000
# 3040       825000
# 3041      1500000
# 3042            0
# 3043       140000
# Name: amount, Length: 3044, dtype: object

# %%
def to_inr(dollar):
    inr = dollar*80
    return inr/10000000

# %%
# Remove non-numeric values and convert to float
df['amount'] = pd.to_numeric(df['amount'], errors='coerce')

# %%
df['amount'] = df['amount'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3044 entries, 0 to 3043
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sno           3044 non-null   int64
#  1   date          3044 non-null   object
#  2   Startup Name  3044 non-null   object
#  3   vertical      2873 non-null   object
#  4   subvertical   2108 non-null   object
#  5   city          2864 non-null   object
#  6   investors     3020 non-null   object
#  7   rounds        3040 non-null   object
#  8   amount        3025 non-null   float64
# dtypes: float64(1), int64(1), object(7)
# memory usage: 214.2+ KB

# %%
df['date']
# Out:
# 0       09/01/2020
# 1       13/01/2020
# 2       09/01/2020
# 3       02/01/2020
# 4       02/01/2020
#            ...
# 3039    29/01/2015
# 3040    29/01/2015
# 3041    30/01/2015
# 3042    30/01/2015
# 3043    31/01/2015
# Name: date, Length: 3044, dtype: object

# %%
df['date']=pd.to_datetime(df['date'],format='%d/%m/%Y',dayfirst=True,errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3044 entries, 0 to 3043
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sno           3044 non-null   int64
#  1   date          3036 non-null   datetime64[ns]
#  2   Startup Name  3044 non-null   object
#  3   vertical      2873 non-null   object
#  4   subvertical   2108 non-null   object
#  5   city          2864 non-null   object
#  6   investors     3020 non-null   object
#  7   rounds        3040 non-null   object
#  8   amount        3025 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(6)
# memory usage: 214.2+ KB

# %%
df = df.rename(columns={
    'Startup Name':'startup'
})
df
# Out:
#        sno       date                       startup             vertical  \
# 0        1 2020-01-09                        BYJU’S               E-Tech
# 1        2 2020-01-13                        Shuttl       Transportation
# 2        3 2020-01-09                     Mamaearth           E-commerce
# 3        4 2020-01-02  https://www.wealthbucket.in/              FinTech
# 4        5 2020-01-02                        Fashor  Fashion and Apparel
# ...    ...        ...                           ...                  ...
# 3039  3040 2015-01-29                    Printvenue                  NaN
# 3040  3041 2015-01-29                      Graphene                  NaN
# 3041  3042 2015-01-30                Mad Street Den                  NaN
# 3042  3043 2015-01-30                     Simplotel                  NaN
# 3043  3044 2015-01-31              couponmachine.in                  NaN
#
#                                 subvertical       city  \
# ...

# %%
df = df.dropna(subset=['date','startup','vertical','subvertical','city','investors','rounds','amount'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2071 entries, 0 to 2107
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sno          2071 non-null   int64
#  1   date         2071 non-null   datetime64[ns]
#  2   startup      2071 non-null   object
#  3   vertical     2071 non-null   object
#  4   subvertical  2071 non-null   object
#  5   city         2071 non-null   object
#  6   investors    2071 non-null   object
#  7   rounds       2071 non-null   object
#  8   amount       2071 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(6)
# memory usage: 161.8+ KB

# %%
import pandas as pd

df = pd.read_csv('startup.csv')
df
# Out:
#       Unnamed: 0   sno        date                       startup  \
# 0              0     1  2020-01-09                        BYJU’S
# 1              1     2  2020-01-13                        Shuttl
# 2              2     3  2020-01-09                     Mamaearth
# 3              3     4  2020-01-02  https://www.wealthbucket.in/
# 4              4     5  2020-01-02                        Fashor
# ...          ...   ...         ...                           ...
# 2066        2103  2104  2016-01-29                    Rare Media
# 2067        2104  2105  2016-01-29                        TinMen
# 2068        2105  2106  2016-01-29                    CodingLabs
# 2069        2106  2107  2016-01-30                   FindUrClass
# 2070        2107  2108  2016-01-30                    DesignBids
#
#                  vertical                             subvertical       city  \
# 0                  E-Tech                              E-learning  Bengaluru
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2071 entries, 0 to 2070
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   2071 non-null   int64
#  1   sno          2071 non-null   int64
#  2   date         2071 non-null   object
#  3   startup      2071 non-null   object
#  4   vertical     2071 non-null   object
#  5   subvertical  2071 non-null   object
#  6   city         2071 non-null   object
#  7   investors    2071 non-null   object
#  8   rounds       2071 non-null   object
#  9   amount       2071 non-null   float64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 161.9+ KB

# %%
df['date']
# Out:
# 0       2020-01-09
# 1       2020-01-13
# 2       2020-01-09
# 3       2020-01-02
# 4       2020-01-02
#            ...
# 2066    2016-01-29
# 2067    2016-01-29
# 2068    2016-01-29
# 2069    2016-01-30
# 2070    2016-01-30
# Name: date, Length: 2071, dtype: object

# %%
pd.to_datetime(df['date'])
# Out:
# 0      2020-01-09
# 1      2020-01-13
# 2      2020-01-09
# 3      2020-01-02
# 4      2020-01-02
#           ...
# 2066   2016-01-29
# 2067   2016-01-29
# 2068   2016-01-29
# 2069   2016-01-30
# 2070   2016-01-30
# Name: date, Length: 2071, dtype: datetime64[ns]

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2071 entries, 0 to 2070
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   2071 non-null   int64
#  1   sno          2071 non-null   int64
#  2   date         2071 non-null   datetime64[ns]
#  3   startup      2071 non-null   object
#  4   vertical     2071 non-null   object
#  5   subvertical  2071 non-null   object
#  6   city         2071 non-null   object
#  7   investors    2071 non-null   object
#  8   rounds       2071 non-null   object
#  9   amount       2071 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(6)
# memory usage: 161.9+ KB

# %%
df['year']=df['date'].dt.year

# %%
df
# Out:
#       Unnamed: 0   sno       date                       startup  \
# 0              0     1 2020-01-09                        BYJU’S
# 1              1     2 2020-01-13                        Shuttl
# 2              2     3 2020-01-09                     Mamaearth
# 3              3     4 2020-01-02  https://www.wealthbucket.in/
# 4              4     5 2020-01-02                        Fashor
# ...          ...   ...        ...                           ...
# 2066        2103  2104 2016-01-29                    Rare Media
# 2067        2104  2105 2016-01-29                        TinMen
# 2068        2105  2106 2016-01-29                    CodingLabs
# 2069        2106  2107 2016-01-30                   FindUrClass
# 2070        2107  2108 2016-01-30                    DesignBids
#
#                  vertical                             subvertical       city  \
# 0                  E-Tech                              E-learning  Bengaluru
# ...

# %%
val = df[df['investors'].str.contains('Tiger Global Management')].groupby('year')['amount']
val.head()
# Out:
# 0       200000000.0
# 50       15000000.0
# 62       60000000.0
# 77       15500000.0
# 83       50000000.0
# 97       26000000.0
# 314      18000000.0
# 518       2000000.0
# 1999    100000000.0
# Name: amount, dtype: float64

# %%
df
# Out:
#       Unnamed: 0   sno       date                       startup  \
# 0              0     1 2020-01-09                        BYJU’S
# 1              1     2 2020-01-13                        Shuttl
# 2              2     3 2020-01-09                     Mamaearth
# 3              3     4 2020-01-02  https://www.wealthbucket.in/
# 4              4     5 2020-01-02                        Fashor
# ...          ...   ...        ...                           ...
# 2066        2103  2104 2016-01-29                    Rare Media
# 2067        2104  2105 2016-01-29                        TinMen
# 2068        2105  2106 2016-01-29                    CodingLabs
# 2069        2106  2107 2016-01-30                   FindUrClass
# 2070        2107  2108 2016-01-30                    DesignBids
#
#                  vertical                             subvertical       city  \
# 0                  E-Tech                              E-learning  Bengaluru
# ...

# %%
# similar investors
similar_investors = []
vertical_list = []
rows = df[df['investors'].str.contains('Tiger Global Management')]['vertical']
for row in rows:
    if row not in vertical_list:
        vertical_list.append(row)

# %%
print(vertical_list)
# Out:
# ['E-Tech', 'FinTech', 'E-Commerce', 'Saas', 'SaaS', 'Technology', 'eCommerce', 'ECommerce']

# %%
tiger_investments = df[df['investors'].str.contains('Tiger Global Management', case=False, na=False)]
print(tiger_investments)
# Out:
#       Unnamed: 0   sno       date    startup    vertical  \
# 0              0     1 2020-01-09     BYJU’S      E-Tech
# 50            55    56 2019-08-22  INDwealth     FinTech
# 62            68    69 2019-07-11     Moglix  E-Commerce
# 77            85    86 2019-06-10   OkCredit     FinTech
# 83            93    94 2019-05-02     Zenoti        Saas
# 97           107   108 2019-04-11  CleverTap        SaaS
# 314          340   341 2018-03-22  Chargebee  Technology
# 518          547   548 2017-10-13    Chaayos   eCommerce
# 1999        2036  2037 2016-01-12  Shopclues   ECommerce
#
#                                             subvertical       city  \
# 0                                            E-learning  Bengaluru
# 50                                    Wealth Management    Gurgaon
# 62                      Industrial Tools and Equipments  Singapore
# 77                                   Financial Services    Haryana
# ...

# %%
tiger_vertical = tiger_investments['vertical'].unique()
tiger_vertical
# Out:
# array(['E-Tech', 'FinTech', 'E-Commerce', 'Saas', 'SaaS', 'Technology',
#        'eCommerce', 'ECommerce'], dtype=object)

# %%
similar_investors = df[df['vertical'].isin(tiger_vertical) & (-df['investors'].str.contains('Tiger Global Manegement'))].groupby('investors')['vertical'].value_counts().unstack()

# %%
similar_investors.head(5)
# Out:
# vertical                                            E-Commerce  E-Tech  \
# investors
# 021 Capita, Binny Bansal                                   NaN     NaN
# 1Crowd                                                     NaN     NaN
# 3 undisclosed HNIs                                         NaN     NaN
# 3one4 Capital, Tracxn Labs, Aaruha Technology F...         NaN     NaN
# 3one4 capital                                              NaN     NaN
#
# vertical                                            ECommerce  FinTech  SaaS  \
# investors
# 021 Capita, Binny Bansal                                  NaN      NaN   NaN
# 1Crowd                                                    NaN      NaN   NaN
# 3 undisclosed HNIs                                        NaN      NaN   NaN
# 3one4 Capital, Tracxn Labs, Aaruha Technology F...        NaN      NaN   NaN
# 3one4 capital                                             NaN      NaN   NaN
#
# ...

# %%
import pandas as pd

# %%
df['amount'].sum()
# Out:
# np.float64(28623333035.0)

# %%
df['amount'].max()
# Out:
# np.float64(3900000000.0)

# %%
df.groupby('startup')['amount'].max().sort_values(ascending=False).head(1).values[0]
# Out:
# np.float64(3900000000.0)

# %%
df.groupby('startup')['amount'].sum().mean()
# Out:
# np.float64(16226379.27154195)

# %%
df['startup'].nunique()
# Out:
# 1764

# %%
# mom funding 

df['month']=df['date'].dt.month

# %%
df
# Out:
#       Unnamed: 0   sno       date                       startup  \
# 0              0     1 2020-01-09                        BYJU’S
# 1              1     2 2020-01-13                        Shuttl
# 2              2     3 2020-01-09                     Mamaearth
# 3              3     4 2020-01-02  https://www.wealthbucket.in/
# 4              4     5 2020-01-02                        Fashor
# ...          ...   ...        ...                           ...
# 2066        2103  2104 2016-01-29                    Rare Media
# 2067        2104  2105 2016-01-29                        TinMen
# 2068        2105  2106 2016-01-29                    CodingLabs
# 2069        2106  2107 2016-01-30                   FindUrClass
# 2070        2107  2108 2016-01-30                    DesignBids
#
#                  vertical                             subvertical       city  \
# 0                  E-Tech                              E-learning  Bengaluru
# ...

# %%
df.groupby(['year','month'])['startup'].count().reset_index()
# Out:
#     year  month  startup
# 0   2016      1      104
# 1   2016      2       99
# 2   2016      3       84
# 3   2016      4       77
# 4   2016      5       79
# 5   2016      6       97
# 6   2016      7       63
# 7   2016      8       87
# 8   2016      9       73
# 9   2016     10       80
# 10  2016     11       72
# 11  2016     12       72
# 12  2017      1       72
# 13  2017      2       48
# 14  2017      3       71
# 15  2017      4       71
# 16  2017      5       67
# 17  2017      6       65
# 18  2017      7       42
# 19  2017      8       45
# 20  2017      9       58
# 21  2017     10       53
# 22  2017     11       50
# 23  2017     12       42
# 24  2018      1       36
# 25  2018      2       42
# 26  2018      3       33
# 27  2018      4       32
# 28  2018      5       22
# 29  2018      6       32
# 30  2018      7       33
# 31  2018      8       21
# 32  2018      9       12
# 33  2018     10        7
# 34  2018     11       17
# 35  2018     12        7
# ...

# %%
temp_df = df.groupby(['year','month'])['amount'].sum().reset_index()

# %%
temp_df['x-axis']=temp_df['month'].astype('str')+'-'+temp_df['year'].astype('str')

# %%
temp_df[['amount','x-axis']]
# Out:
#           amount   x-axis
# 0   6.998800e+08   1-2016
# 1   3.314905e+08   2-2016
# 2   3.095616e+08   3-2016
# 3   2.539400e+08   4-2016
# 4   3.398400e+08   5-2016
# 5   1.996390e+08   6-2016
# 6   2.335470e+08   7-2016
# 7   5.340890e+08   8-2016
# 8   2.413610e+08   9-2016
# 9   2.374480e+08  10-2016
# 10  2.599970e+08  11-2016
# 11  1.872430e+08  12-2016
# 12  2.532335e+08   1-2017
# 13  2.949590e+08   2-2017
# 14  2.264281e+09   3-2017
# 15  7.323950e+08   4-2017
# 16  1.786669e+09   5-2017
# 17  3.448180e+08   6-2017
# 18  1.677040e+08   7-2017
# 19  2.748139e+09   8-2017
# 20  5.365020e+08   9-2017
# 21  4.003870e+08  10-2017
# 22  6.158022e+08  11-2017
# 23  2.817200e+08  12-2017
# 24  3.448746e+08   1-2018
# 25  1.211217e+09   2-2018
# 26  2.917030e+08   3-2018
# 27  1.965816e+08   4-2018
# 28  1.056620e+08   5-2018
# 29  3.914750e+08   6-2018
# 30  5.504780e+08   7-2018
# 31  2.072400e+08   8-2018
# 32  6.000900e+08   9-2018
# 33  5.288000e+07  10-2018
# ...

# %%
df
# Out:
#       Unnamed: 0   sno       date                       startup  \
# 0              0     1 2020-01-09                        BYJU’S
# 1              1     2 2020-01-13                        Shuttl
# 2              2     3 2020-01-09                     Mamaearth
# 3              3     4 2020-01-02  https://www.wealthbucket.in/
# 4              4     5 2020-01-02                        Fashor
# ...          ...   ...        ...                           ...
# 2066        2103  2104 2016-01-29                    Rare Media
# 2067        2104  2105 2016-01-29                        TinMen
# 2068        2105  2106 2016-01-29                    CodingLabs
# 2069        2106  2107 2016-01-30                   FindUrClass
# 2070        2107  2108 2016-01-30                    DesignBids
#
#                  vertical                             subvertical       city  \
# 0                  E-Tech                              E-learning  Bengaluru
# ...

# %%
df.groupby('year').count()
# Out:
#       Unnamed: 0  sno  date  startup  vertical  subvertical  city  investors  \
# year
# 2016         987  987   987      987       987          987   987        987
# 2017         684  684   684      684       684          684   684        684
# 2018         294  294   294      294       294          294   294        294
# 2019          99   99    99       99        99           99    99         99
# 2020           7    7     7        7         7            7     7          7
#
#       rounds  amount  month
# year
# 2016     987     987    987
# 2017     684     684    684
# 2018     294     294    294
# 2019      99      99     99
# 2020       7       7      7

# %%
temp_year = df[df['year']==2016]

# %%
total_startup = temp_year.groupby('month')['startup'].count()

# %%
total_startup.reset_index()
# Out:
#     month  startup
# 0       1      104
# 1       2       99
# 2       3       84
# 3       4       77
# 4       5       79
# 5       6       97
# 6       7       63
# 7       8       87
# 8       9       73
# 9      10       80
# 10     11       72
# 11     12       72

# %%
df
# Out:
#       Unnamed: 0   sno       date                       startup  \
# 0              0     1 2020-01-09                        BYJU’S
# 1              1     2 2020-01-13                        Shuttl
# 2              2     3 2020-01-09                     Mamaearth
# 3              3     4 2020-01-02  https://www.wealthbucket.in/
# 4              4     5 2020-01-02                        Fashor
# ...          ...   ...        ...                           ...
# 2066        2103  2104 2016-01-29                    Rare Media
# 2067        2104  2105 2016-01-29                        TinMen
# 2068        2105  2106 2016-01-29                    CodingLabs
# 2069        2106  2107 2016-01-30                   FindUrClass
# 2070        2107  2108 2016-01-30                    DesignBids
#
#                  vertical                             subvertical       city  \
# 0                  E-Tech                              E-learning  Bengaluru
# ...

# %%
df.groupby('city').count()
# Out:
#                Unnamed: 0  sno  date  startup  vertical  subvertical  \
# city
# Agra                    2    2     2        2         2            2
# Ahemadabad              1    1     1        1         1            1
# Ahemdabad               1    1     1        1         1            1
# Ahmedabad              28   28    28       28        28           28
# Amritsar                1    1     1        1         1            1
# ...                   ...  ...   ...      ...       ...          ...
# Udaipur                 1    1     1        1         1            1
# Udupi                   1    1     1        1         1            1
# Uttar Pradesh           1    1     1        1         1            1
# Vadodara                7    7     7        7         7            7
# Varanasi                1    1     1        1         1            1
#
#                investors  rounds  amount  year  month
# city
# Agra                   2       2       2     2      2
# ...

# %%
val = set(df['vertical'])

# %%
df.groupby('rounds').count()
# Out:
#                              Unnamed: 0  sno  date  startup  vertical  \
# rounds
# Angel                                 1    1     1        1         1
# Angel / Seed Funding                  8    8     8        8         8
# Angel Funding                         1    1     1        1         1
# Angel Round                           1    1     1        1         1
# Corporate Round                       1    1     1        1         1
# Debt Funding                         23   23    23       23        23
# Debt and Preference capital           1    1     1        1         1
# Debt-Funding                          1    1     1        1         1
# Equity                                2    2     2        2         2
# Equity Based Funding                  1    1     1        1         1
# Funding Round                         1    1     1        1         1
# Inhouse Funding                       1    1     1        1         1
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 df['startup']('date')
#
# TypeError: 'Series' object is not callable

# %%
df[df['startup']=='BYJU’S']['vertical']
# Out:
# 0    E-Tech
# Name: vertical, dtype: object

# %%
df[df['startup']=='BYJU’S']
# Out:
#    Unnamed: 0  sno       date startup vertical subvertical       city  \
# 0           0    1 2020-01-09  BYJU’S   E-Tech  E-learning  Bengaluru
#
#                  investors                rounds       amount  year  month
# 0  Tiger Global Management  Private Equity Round  200000000.0  2020      1

# %%
st = df[df['startup']=='Zomato']

# %%
st.plot(x = 'investors', y='amount',kind = 'bar')
# Out:
# <Axes: xlabel='investors'>

# %%
st[['investors','amount']]
# Out:
#           investors       amount
# 6     Ant Financial  150000000.0
# 324  Ant Financials  200000000.0
